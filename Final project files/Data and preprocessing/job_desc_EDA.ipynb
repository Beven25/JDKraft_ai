# %%
import pandas as pd

# %%
df=pd.read_csv('job_descriptions.csv')

# %%
df=df.head(1000)

# %%
df.columns
# Out:
# Index(['Job Id', 'Experience', 'Qualifications', 'Salary Range', 'location',
#        'Country', 'latitude', 'longitude', 'Work Type', 'Company Size',
#        'Job Posting Date', 'Preference', 'Contact Person', 'Contact',
#        'Job Title', 'Role', 'Job Portal', 'Job Description', 'Benefits',
#        'skills', 'Responsibilities', 'Company', 'Company Profile'],
#       dtype='object')

# %%
columns_to_drop = ['Job Id', 'latitude','longitude','Job Posting Date','Preference','Job Portal']
df = df.drop(columns=columns_to_drop)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Experience        1000 non-null   object
#  1   Qualifications    1000 non-null   object
#  2   Salary Range      1000 non-null   object
#  3   location          1000 non-null   object
#  4   Country           1000 non-null   object
#  5   Work Type         1000 non-null   object
#  6   Company Size      1000 non-null   int64
#  7   Contact Person    1000 non-null   object
#  8   Contact           1000 non-null   object
#  9   Job Title         1000 non-null   object
#  10  Role              1000 non-null   object
#  11  Job Description   1000 non-null   object
#  12  Benefits          1000 non-null   object
#  13  skills            1000 non-null   object
#  14  Responsibilities  1000 non-null   object
#  15  Company           1000 non-null   object
# ...

# %% [markdown]
# # lets do a proper EDA

# %%
#Experience coloumn

# %%
top_values = df['Experience'].value_counts().head(20)

# %%
top_values
# Out:
# 1 to 10 Years    30
# 5 to 15 Years    29
# 4 to 8 Years     27
# 1 to 15 Years    27
# 5 to 8 Years     26
# 2 to 12 Years    26
# 5 to 14 Years    26
# 5 to 9 Years     25
# 1 to 8 Years     25
# 0 to 14 Years    25
# 0 to 12 Years    24
# 1 to 11 Years    24
# 2 to 9 Years     23
# 4 to 13 Years    23
# 0 to 11 Years    23
# 2 to 13 Years    22
# 1 to 13 Years    22
# 2 to 10 Years    22
# 0 to 10 Years    22
# 4 to 12 Years    22
# Name: Experience, dtype: int64

# %%
# Check for missing values in 'Experience'
missing_values = df['Experience'].isnull().any()

print("Are there missing values in 'Experience'? :", missing_values)
# Out:
# Are there missing values in 'Experience'? : False

# %%
#possible transformations: Converting of numbers into words

# %%
#Qualifications coloumn

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Combine all text in the column
all_text = ' '.join(df['Qualifications'])

wordcloud = WordCloud(width=800, height=400, max_words=100, background_color='white').generate(all_text)

plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Text Column')
plt.show()

# %%
top_values = df['Qualifications'].value_counts().head(20)

# %%
top_values
# Out:
# BA        110
# M.Tech    109
# B.Tech    107
# B.Com     103
# PhD       102
# MBA       102
# M.Com      95
# BCA        92
# MCA        91
# BBA        89
# Name: Qualifications, dtype: int64

# %%
# Check for missing values in 'Qualifications'
missing_values = df['Qualifications'].isnull().any()

print("Are there missing values in 'Qualifications'? :", missing_values)
# Out:
# Are there missing values in 'Qualifications'? : False

# %%
#Possible transformations: Expansion of these proper terms

# %%
#Salary Range coloumns

# %%
top_values = df['Salary Range'].value_counts().head(10)

# %%
top_values
# Out:
# $56K-$116K    7
# $63K-$85K     7
# $55K-$111K    7
# $59K-$114K    6
# $63K-$102K    6
# $62K-$129K    6
# $65K-$107K    6
# $63K-$101K    5
# $60K-$129K    5
# $59K-$101K    5
# Name: Salary Range, dtype: int64

# %%
# Check for missing values in 'Salary Range'
missing_values = df['Salary Range'].isnull().any()

print("Are there missing values in 'Salary Range'? :", missing_values)
# Out:
# Are there missing values in 'Salary Range'? : False

# %%
#Possible transformations: Expansion of these proper terms

# %%
#location col

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Combine all text in the column
all_text = ' '.join(df['location'])

wordcloud = WordCloud(width=800, height=400, max_words=100, background_color='white').generate(all_text)

plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Text Column')
plt.show()

# %%
# Check for missing values in 'location'
missing_values = df['location'].isnull().any()

print("Are there missing values in 'location'? :", missing_values)
# Out:
# Are there missing values in 'location'? : False

# %%
top_values = df['location'].value_counts().head(10)

# %%
top_values
# Out:
# Amman                  11
# Bandar Seri Begawan    10
# Port Moresby           10
# Yaounde                10
# Bishkek                 9
# Honiara                 9
# Funafuti                9
# Moroni                  9
# Kigali                  9
# London                  9
# Name: location, dtype: int64

# %%
#There are improper strcture in location coloumn, can use a location mapper to map it properly

# %%
#Country coloumn

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Combine all text in the column
all_text = ' '.join(df['Country'])

wordcloud = WordCloud(width=800, height=400, max_words=100, background_color='white').generate(all_text)

plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Text Column')
plt.show()

# %%
# Check for missing values in 'Country'
missing_values = df['Country'].isnull().any()

print("Are there missing values in 'Country'? :", missing_values)
# Out:
# Are there missing values in 'Country'? : False

# %%
#There are improper strcture in location coloumn, can use a location mapper to map it properly

# %%
#Work Type col

# %%
top_values = df['Work Type'].value_counts().head(10)

# %%
top_values
# Out:
# Part-Time    220
# Temporary    199
# Contract     198
# Full-Time    194
# Intern       189
# Name: Work Type, dtype: int64

# %%
# Check for missing values in 'Country'
missing_values = df['Work Type'].isnull().any()

print("Are there missing values in 'Work Type'? :", missing_values)
# Out:
# Are there missing values in 'Work Type'? : False

# %%
#Company Size col

# %%
df['Company Size'][2]
# Out:
# 84525

# %%
type(df['Company Size'][2])
# Out:
# numpy.int64

# %%
# Check for missing values in 'Country'
missing_values = df['Company Size'].isnull().any()

print("Are there missing values in 'Company Size'? :", missing_values)
# Out:
# Are there missing values in 'Company Size'? : False

# %%
#Contact Person col

# %%
df['Contact Person'][2]
# Out:
# 'Gary Gibson'

# %%
# Check for missing values in 'Country'
missing_values = df['Contact Person'].isnull().any()

print("Are there missing values in 'Contact Person'? :", missing_values)
# Out:
# Are there missing values in 'Contact Person'? : False

# %%
#can be mapped to NER tags

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
#Checking the rest of the features

# %%
feat=['Contact','Job Title','Role','Job Description','Benefits','skills','Responsibilities','Company','Company Profile']

# %%
for F in feat:
    missing_values = df[F].isnull().any()
    print("Are there missing values in "+F+"? :", missing_values)
# Out:
# Are there missing values in Contact? : False
# Are there missing values in Job Title? : False
# Are there missing values in Role? : False
# Are there missing values in Job Description? : False
# Are there missing values in Benefits? : False
# Are there missing values in skills? : False
# Are there missing values in Responsibilities? : False
# Are there missing values in Company? : False
# Are there missing values in Company Profile? : True

# %%
#In the contact coloumn, there are x placed inbetween the contact number to mask it, can be replaced by a random number

# %%
#As there is Missing values in Company Profile

# %%
df['Company Profile'][22]
# Out:
# '{"Sector":"Elevators & Escalators","Industry":"Industrial Machinery","City":"Farmington","State":"Connecticut","Zip":"6032","Website":"www.otis.com","Ticker":"OTIS","CEO":"Judith F. Marks"}'

# %%
#This Company profile feature can be converted into 3 col: Sector, Industry, Website
